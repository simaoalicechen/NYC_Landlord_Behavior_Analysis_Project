# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib
import matplotlib.pyplot as plt
import os
import io
import geopandas as gpd
import seaborn as sns

# suppress warning
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# get them back from the cloud
# the reduced version should only have 10 columns
saved_2017 = "/content/drive/My Drive/X999/311_different_years/filtered_df_2017_reduced.csv"
saved_2018 = "/content/drive/My Drive/X999/311_different_years/filtered_df_2018_reduced.csv"
saved_2019 = "/content/drive/My Drive/X999/311_different_years/filtered_df_2019_reduced.csv"
saved_2020 = "/content/drive/My Drive/X999/311_different_years/filtered_df_2020_reduced.csv"
saved_2021 = "/content/drive/My Drive/X999/311_different_years/filtered_df_2021_reduced.csv"
saved_2022 = "/content/drive/My Drive/X999/311_different_years/filtered_df_2022_reduced.csv"
saved_2023 = "/content/drive/My Drive/X999/311_different_years/filtered_df_2023_reduced.csv"
saved_2024 = "/content/drive/My Drive/X999/311_different_years/filtered_df_2024_reduced.csv"

# %%
df_2017 = pd.read_csv(saved_2017)
df_2018 = pd.read_csv(saved_2018)
df_2019 = pd.read_csv(saved_2019)
df_2020 = pd.read_csv(saved_2020)
df_2021 = pd.read_csv(saved_2021)
df_2022 = pd.read_csv(saved_2022)
df_2023 = pd.read_csv(saved_2023)
df_2024 = pd.read_csv(saved_2024)

# %%
df_2017.shape, df_2018.shape, df_2019.shape, df_2020.shape, df_2021.shape, df_2022.shape, df_2023.shape, df_2024.shape
# Out:
# ((1032946, 10),
#  (1066249, 10),
#  (996996, 10),
#  (1263463, 10),
#  (1355688, 10),
#  (1433295, 10),
#  (1412135, 10),
#  (1527906, 10))

# %%
all_years_df = pd.concat([df_2017, df_2018, df_2019, df_2023, df_2024])

# %%
covid_311_df = pd.concat([df_2020, df_2021, df_2022])

# %%
all_years_df.shape, all_years_df.columns
# Out:
# ((6036232, 10),
#  Index(['unique_key', 'created_date', 'closed_date', 'complaint_type',
#         'incident_zip', 'incident_address', 'bbl', 'borough', 'latitude',
#         'longitude'],
#        dtype='object'))

# %%
all_years_df.bbl[0].dtype
# Out:
# dtype('float64')

# %%
all_years_df.bbl = all_years_df.bbl.astype('int64')

# %%
saved_bbl_evictions = "/content/drive/My Drive/X999/bbl_evictions_merged.csv"

# %%
bbl_evictions = pd.read_csv(saved_bbl_evictions)

# %%
bbl_evictions.shape
# Out:
# (74082, 40)

# %%
bbl_evictions.columns
# Out:
# Index(['court_index_number', 'docket_number', 'eviction_address',
#        'eviction_apartment_number', 'executed_date', 'borough',
#        'eviction_postcode', 'ejectment', 'eviction/legal_possession',
#        'latitude', 'longitude', 'community_board', 'council_district',
#        'census_tract', 'bin', 'bbl', 'nta', 'geometry', 'eviction_count',
#        'year', 'average_year_eviction_count', 'bbl_clean', 'yearbuilt',
#        'bldgclass', 'numfloors', 'unitsres', 'ownername', 'bldgarea',
#        'building_type', 'building_category', 'is_condo', 'floor_category',
#        'rent_era', 'architectural_style', 'economic_period',
#        'residential_units_category', 'is_llc', 'building_size_category',
#        'size_quartile', 'decade'],
#       dtype='object')

# %%
bbl_evictions.bbl_clean[0].dtype, all_years_df.bbl[0].dtype, all_years_df.bbl[0]
# Out:
# (dtype('int64'),
#  dtype('int64'),
#  0    1019200007
#  0    2024830015
#  0    3088440010
#  0    4021460028
#  0    1020570056
#  Name: bbl, dtype: int64)

# %%
all_years_df.bbl = all_years_df.bbl.astype('int64')

# %%
all_years_df.bbl[0].dtype
# Out:
# dtype('int64')

# %%
all_years_df.bbl, bbl_evictions.bbl_clean
# Out:
# (0          1019200007
#  1          1017540155
#  2          2050540041
#  3          3066870049
#  4          3050860041
#                ...
#  1527901    4090210002
#  1527902    4013110066
#  1527903    4091250055
#  1527904    3043710001
#  1527905    2032367501
#  Name: bbl, Length: 6036232, dtype: int64,
#  0        2047200001
#  1        2029990111
#  2        1016160001
#  3        3046980037
#  4        2026110033
#              ...
#  74077    1020510138
#  74078    1010420061
#  74079    3013810057
#  74080    1002060004
#  74081    1021390329
#  Name: bbl_clean, Length: 74082, dtype: int64)

# %%
# pandas.Series.isin() returns a boolean mask of values in the first series that also appear in the second
overlap_mask = bbl_evictions.bbl_clean.isin(all_years_df.bbl)
overlapping_values = bbl_evictions.bbl_clean[overlap_mask]
num_overlaps = overlap_mask.sum()
num_overlaps
# pretty good, given the bbl_evictions_df.shape is (74082, 40)
# (71149 / 74082)) # 96%
# Out:
# np.int64(69551)

# %%
all_years_df.head()
# Out:
#    unique_key         created_date          closed_date  \
# 0    38070156  2017-12-31 23:59:35  2018-01-04 19:27:02
# 1    38067146  2017-12-31 23:59:34  2018-01-01 00:57:19
# 2    38066214  2017-12-31 23:59:15  2018-01-01 02:48:23
# 3    38067041  2017-12-31 23:58:38  2018-01-01 02:53:28
# 4    38068229  2017-12-31 23:58:33  2018-01-08 13:30:58
#
#             complaint_type  incident_zip      incident_address         bbl  \
# 0           HEAT/HOT WATER         10030  181 WEST  135 STREET  1019200007
# 1      Noise - Residential         10035   2048 MADISON AVENUE  1017540155
# 2      Noise - Residential         10466    1902 NEREID AVENUE  2050540041
# 3  Noise - Street/Sidewalk         11230         1201 AVENUE H  3066870049
# 4           HEAT/HOT WATER         11226   70 LINDEN BOULEVARD  3050860041
#
#      borough  latitude  longitude
# 0  MANHATTAN        41        -74
# 1  MANHATTAN        41        -74
# 2      BRONX        41        -74
# 3   BROOKLYN        41        -74
# 4   BROOKLYN        41        -74

# %% [markdown]
# ### 96% of the buildings that had evictions also had 311 complaints

# %%
# or use sets, but this only shows the unique overlapped bbl numbers
# (faster for large datasets)
set1 = set(bbl_evictions.bbl_clean)
set2 = set(all_years_df.bbl)
unique_overlap = set1.intersection(set2)
len(unique_overlap)
# Out:
# 29168

# %%
# numpy.intersect1d()
overlapping_values = np.intersect1d(bbl_evictions.bbl_clean, all_years_df.bbl)
len(overlapping_values)
# Out:
# 29168

# %%
bbl_evictions.head()
# Out:
#   court_index_number  docket_number        eviction_address  \
# 0           34859/16          53416     3476 SEYMOUR AVENUE
# 1          B57808/16          74242      1426 BRYANT AVENUE
# 2         N069212/14         355977         1309 5TH AVENUE
# 3         K065455/16         367441      458 EAST 51 STREET
# 4           33992/16         458984  580 EAST 168TH STREE T
#
#   eviction_apartment_number executed_date    borough  eviction_postcode  \
# 0                       3-B    2017-01-03      BRONX              10469
# 1        10 AKA 2ND FL UNIT    2017-01-03      BRONX              10459
# 2                       24H    2017-01-03  MANHATTAN              10029
# 3                        6A    2017-01-03   BROOKLYN              11203
# 4                         *    2017-01-03      BRONX              10456
#
#           ejectment eviction/legal_possession  latitude  ...  is_condo  \
# 0  Not an Ejectment                Possession        41  ...     False
# 1  Not an Ejectment                Possession        41  ...     False
# 2  Not an Ejectment                Possession        41  ...     False
# 3  Not an Ejectment                Possession        41  ...     False
# 4  Not an Ejectment                Possession        41  ...       NaN
#
#    floor_category                         rent_era  \
# 0        mid-rise       Pre-1947, pre-rent-control
# 1        low-rise  1994–Present, vacancy decontrol
# 2       high-rise      1970–1993, deregularization
# 3        mid-rise       Pre-1947, pre-rent-control
# 4             NaN                              NaN
#
#                                  architectural_style  \
# 0                        1931–1950, Manhattan Modern
# 1                          1981–2000, Post-Modernism
# 2  1951–1980, the International Style, Alternativ...
# 3                        1931–1950, Manhattan Modern
# 4                                                NaN
#
#                         economic_period  residential_units_category is_llc  \
# 0  1930-1945, great depression and WWII                  100+ units   True
# 1     1991–2008, modern economic growth                      2-unit  False
# 2      1946–1975, pst war economic boom                  100+ units  False
# 3  1930-1945, great depression and WWII                21-100 units   True
# 4                                   NaN                         NaN    NaN
#
#   building_size_category     size_quartile     decade
# 0                   mega  Q4 (largest 25%)  1930-1939
# 1                  small       Q3 (50-75%)  1990-1999
# 2                   mega  Q4 (largest 25%)  1970-1979
# 3             very large  Q4 (largest 25%)  1940-1949
# 4                    NaN               NaN        NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Buildings that received most frequent complaints

# %%
complaint_counts_by_bbl = all_years_df.groupby('bbl').size().reset_index(name='complaint_count')
complaint_counts_by_bbl = complaint_counts_by_bbl.sort_values('complaint_count', ascending=False)

# %%
complaint_counts_by_bbl.head(1)
# Out:
#               bbl  complaint_count
# 71563  2048330028            56960

# %% [markdown]
# A multi family 2 floor building in the Bronx

# %%
complaint_stats = complaint_counts_by_bbl['complaint_count'].describe()
complaint_stats
# Out:
# count   342961
# mean        18
# std        132
# min          1
# 25%          1
# 50%          2
# 75%          8
# max      56960
# Name: complaint_count, dtype: float64

# %%
additional_stats = {
    'median': f"{complaint_counts_by_bbl['complaint_count'].median():.0f}",
    'mode': f"{complaint_counts_by_bbl['complaint_count'].mode()[0]:.0f}",
    'range': f"{complaint_counts_by_bbl['complaint_count'].max() - complaint_counts_by_bbl['complaint_count'].min():.0f}",
    'iqr': f"{complaint_counts_by_bbl['complaint_count'].quantile(0.75) - complaint_counts_by_bbl['complaint_count'].quantile(0.25):.0f}",
    'skew': f"{complaint_counts_by_bbl['complaint_count'].skew():.2f}",
    'kurtosis': f"{complaint_counts_by_bbl['complaint_count'].kurtosis():.2f}",
    'sum': f"{complaint_counts_by_bbl['complaint_count'].sum():.0f}",
    'variance': f"{complaint_counts_by_bbl['complaint_count'].var():.0f}"
}
additional_stats
# Out:
# {'median': '2',
#  'mode': '1',
#  'range': '56959',
#  'iqr': '7',
#  'skew': '243.52',
#  'kurtosis': '100599.53',
#  'sum': '6036232',
#  'variance': '17503'}

# %%
top_complaint_buildings = complaint_counts_by_bbl.head(400)
top_complaint_buildings
# Out:
#                bbl  complaint_count
# 71563   2048330028            56960
# 40164   2025110068            10091
# 226265  4015110001             9836
# 264459  4068290001             9662
# 46457   2029020036             8165
# ...            ...              ...
# 51831   2032140030              923
# 32724   1020360038              923
# 54547   2033280171              922
# 35440   1021490093              922
# 2600    1003380001              922
#
# [400 rows x 2 columns]

# %%
bbl_evictions.bbl.dtype, bbl_evictions.bbl_clean.dtype, all_years_df.bbl.dtype
# Out:
# (dtype('float64'), dtype('int64'), dtype('int64'))

# %%
bbl_evictions = bbl_evictions.drop(columns=['bbl'])
bbl_evictions = bbl_evictions.rename(columns={'bbl_clean': 'bbl'})

# %%
bbl_evictions['bbl'] = bbl_evictions['bbl'].astype('int64')
all_years_df['bbl'] = all_years_df['bbl'].astype('int64')

# %%
complaints_by_bbl = all_years_df.groupby('bbl').size().reset_index(name='complaint_count')

# %%
complaints_by_bbl.head()
# Out:
#           bbl  complaint_count
# 0           0             1335
# 1   144969020                2
# 2  1000010010               25
# 3  1000010101                1
# 4  1000020001                5

# %%
bbl_evcitions_311_df = pd.merge(
    bbl_evictions,
    complaints_by_bbl,
    on='bbl',
    how='left'
)

# %%
bbl_evcitions_311_df.head()
# Out:
#   court_index_number  docket_number        eviction_address  \
# 0           34859/16          53416     3476 SEYMOUR AVENUE
# 1          B57808/16          74242      1426 BRYANT AVENUE
# 2         N069212/14         355977         1309 5TH AVENUE
# 3         K065455/16         367441      458 EAST 51 STREET
# 4           33992/16         458984  580 EAST 168TH STREE T
#
#   eviction_apartment_number executed_date    borough  eviction_postcode  \
# 0                       3-B    2017-01-03      BRONX              10469
# 1        10 AKA 2ND FL UNIT    2017-01-03      BRONX              10459
# 2                       24H    2017-01-03  MANHATTAN              10029
# 3                        6A    2017-01-03   BROOKLYN              11203
# 4                         *    2017-01-03      BRONX              10456
#
#           ejectment eviction/legal_possession  latitude  ...  floor_category  \
# 0  Not an Ejectment                Possession     40.88  ...        mid-rise
# 1  Not an Ejectment                Possession     40.83  ...        low-rise
# 2  Not an Ejectment                Possession     40.80  ...       high-rise
# 3  Not an Ejectment                Possession     40.65  ...        mid-rise
# 4  Not an Ejectment                Possession     40.83  ...             NaN
#
#                           rent_era  \
# 0       Pre-1947, pre-rent-control
# 1  1994–Present, vacancy decontrol
# 2      1970–1993, deregularization
# 3       Pre-1947, pre-rent-control
# 4                              NaN
#
#                                  architectural_style  \
# 0                        1931–1950, Manhattan Modern
# 1                          1981–2000, Post-Modernism
# 2  1951–1980, the International Style, Alternativ...
# 3                        1931–1950, Manhattan Modern
# 4                                                NaN
#
#                         economic_period  residential_units_category is_llc  \
# 0  1930-1945, great depression and WWII                  100+ units   True
# 1     1991–2008, modern economic growth                      2-unit  False
# 2      1946–1975, pst war economic boom                  100+ units  False
# 3  1930-1945, great depression and WWII                21-100 units   True
# 4                                   NaN                         NaN    NaN
#
#   building_size_category     size_quartile     decade  complaint_count
# 0                   mega  Q4 (largest 25%)  1930-1939           191.00
# 1                  small       Q3 (50-75%)  1990-1999             2.00
# 2                   mega  Q4 (largest 25%)  1970-1979          1724.00
# 3             very large  Q4 (largest 25%)  1940-1949           224.00
# 4                    NaN               NaN        NaN             1.00
#
# [5 rows x 40 columns]

# %%
nan_count = bbl_evcitions_311_df['complaint_count'].isna().sum()
nan_count, \
print(f"percentage of rows with missing complaint_count: {nan_count / len(bbl_evcitions_311_df) * 100:.2f}%")
# about 6.12 of buildings do not have any 311 complaints in those five years.
# safe to ignore them and just fillna
# Out:
# percentage of rows with missing complaint_count: 6.12%
# (np.int64(4531), None)

# %%
bbl_evcitions_311_df['complaint_count'] = bbl_evcitions_311_df['complaint_count'].fillna(0)
# fill the nan cells with 0

# %%
# correlation between eviction counts and complaint counts
eviction_complaint_corr = bbl_evcitions_311_df.groupby('bbl').agg({
    'court_index_number': 'count',
    'complaint_count': 'first'
}).corr()
print("Correlation between evictions and complaints:")
print(eviction_complaint_corr)
# Out:
# Correlation between evictions and complaints:
#                     court_index_number  complaint_count
# court_index_number                1.00             0.32
# complaint_count                   0.32             1.00

# %%
bbl_evcitions_311_df.to_csv('/content/drive/My Drive/X999/bbl_evcitions_311_df_groupby_bbl.csv', index=False)

# %% [markdown]
# ## To preserve all the complaint type details and find their correlations between the complaint types and the number of evictions, we need to do a simple merge that will result with most details.

# %%
all_years_df.shape, bbl_evictions.shape
# Out:
# ((6036232, 10), (74082, 39))

# %%
merged_df = all_years_df.merge(bbl_evictions, on='bbl', how='inner')

# %%
# too large, decided not to save
# merged_df.to_csv('/content/drive/My Drive/X999/bbl_evcitions_311_df_outside_covid.csv', index=False)

# %%
merged_df.shape
# Out:
# (23687576, 48)

# %%
evictions_per_bbl = merged_df.groupby('bbl')['court_index_number'].nunique().reset_index(name='eviction_count')
evictions_per_bbl
# Out:
#               bbl  eviction_count
# 0               0               3
# 1      1000077501               2
# 2      1000157501               4
# 3      1000157502               3
# 4      1000160015               1
# ...           ...             ...
# 29163  5080220054               1
# 29164  5080260130               2
# 29165  5080280074               1
# 29166  5080460052               1
# 29167  5080480039               1
#
# [29168 rows x 2 columns]

# %%
# create counts of each complaint type per bbl
complaint_types = merged_df[['bbl', 'complaint_type']].copy()
complaint_dummies = pd.get_dummies(complaint_types, columns=['complaint_type'])
complaint_counts = complaint_dummies.groupby('bbl').sum()

# %%
analysis_df = evictions_per_bbl.set_index('bbl').join(complaint_counts)

# %%
dict_of_correlations = {}
for column in complaint_counts.columns:
    correlation = analysis_df['eviction_count'].corr(analysis_df[column])
    dict_of_correlations[column.replace('complaint_type_', '')] = correlation

# %%
sorted_correlations = dict(sorted(dict_of_correlations.items(), key=lambda item: item[1], reverse=True))
for complaint_type, correlation in sorted_correlations.items():
    print(f"Complaint type: {complaint_type}, correlation with evictions: {correlation:.3f}")
# Out:
# Complaint type: FLOORING/STAIRS, correlation with evictions: 0.732
# Complaint type: DOOR/WINDOW, correlation with evictions: 0.707
# Complaint type: ELECTRIC, correlation with evictions: 0.696
# Complaint type: PAINT/PLASTER, correlation with evictions: 0.692
# Complaint type: General Construction/Plumbing, correlation with evictions: 0.688
# Complaint type: SAFETY, correlation with evictions: 0.677
# Complaint type: Animal Abuse, correlation with evictions: 0.670
# Complaint type: UNSANITARY CONDITION, correlation with evictions: 0.667
# Complaint type: Indoor Air Quality, correlation with evictions: 0.659
# Complaint type: GENERAL, correlation with evictions: 0.640
# Complaint type: Plumbing, correlation with evictions: 0.623
# Complaint type: Animal-Abuse, correlation with evictions: 0.615
# Complaint type: Noise, correlation with evictions: 0.611
# Complaint type: PLUMBING, correlation with evictions: 0.604
# Complaint type: Noise - Residential, correlation with evictions: 0.603
# Complaint type: Unsanitary Condition, correlation with evictions: 0.598
# Complaint type: WATER LEAK, correlation with evictions: 0.598
# Complaint type: Paint/Plaster, correlation with evictions: 0.586
# Complaint type: Homeless Person Assistance, correlation with evictions: 0.579
# Complaint type: ELEVATOR, correlation with evictions: 0.564
# Complaint type: Elevator, correlation with evictions: 0.563
# Complaint type: Asbestos, correlation with evictions: 0.547
# Complaint type: Noise - Street/Sidewalk, correlation with evictions: 0.535
# Complaint type: Noise - Vehicle, correlation with evictions: 0.515
# Complaint type: APPLIANCE, correlation with evictions: 0.497
# Complaint type: HEAT/HOT WATER, correlation with evictions: 0.493
# Complaint type: Indoor Sewage, correlation with evictions: 0.488
# Complaint type: Mold, correlation with evictions: 0.482
# Complaint type: OUTSIDE BUILDING, correlation with evictions: 0.470
# Complaint type: Unsanitary Animal Pvt Property, correlation with evictions: 0.454
# Complaint type: Smoking, correlation with evictions: 0.453
# Complaint type: Water Leak, correlation with evictions: 0.452
# Complaint type: General, correlation with evictions: 0.413
# Complaint type: Appliance, correlation with evictions: 0.410
# Complaint type: Posting Advertisement, correlation with evictions: 0.409
# Complaint type: Door/Window, correlation with evictions: 0.391
# Complaint type: Illegal Fireworks, correlation with evictions: 0.387
# Complaint type: Drinking Water, correlation with evictions: 0.384
# Complaint type: Non-Residential Heat, correlation with evictions: 0.381
# Complaint type: Unsanitary Pigeon Condition, correlation with evictions: 0.346
# Complaint type: Flooring/Stairs, correlation with evictions: 0.344
# Complaint type: Urinating in Public, correlation with evictions: 0.321
# Complaint type: Noise - Park, correlation with evictions: 0.308
# Complaint type: Mosquitoes, correlation with evictions: 0.307
# Complaint type: Graffiti, correlation with evictions: 0.304
# Complaint type: Harboring Bees/Wasps, correlation with evictions: 0.302
# Complaint type: Standing Water, correlation with evictions: 0.273
# Complaint type: Collection Truck Noise, correlation with evictions: 0.271
# Complaint type: Day Care, correlation with evictions: 0.242
# Complaint type: Rodent, correlation with evictions: 0.219
# Complaint type: Noise - Commercial, correlation with evictions: 0.217
# Complaint type: Construction Safety Enforcement, correlation with evictions: 0.208
# Complaint type: Bike/Roller/Skate Chronic, correlation with evictions: 0.207
# Complaint type: Homeless Encampment, correlation with evictions: 0.207
# Complaint type: Safety, correlation with evictions: 0.173
# Complaint type: Heat/Hot Water, correlation with evictions: 0.172
# Complaint type: Non-Emergency Police Matter, correlation with evictions: 0.169
# Complaint type: Noise - House of Worship, correlation with evictions: 0.142
# Complaint type: Panhandling, correlation with evictions: 0.139
# Complaint type: Disorderly Youth, correlation with evictions: 0.126
# Complaint type: Encampment, correlation with evictions: 0.122
# Complaint type: Food Poisoning, correlation with evictions: 0.103
# Complaint type: Electric, correlation with evictions: 0.097
# Complaint type: Noise - Helicopter, correlation with evictions: 0.079
# Complaint type: Vending, correlation with evictions: 0.071
# Complaint type: Drinking, correlation with evictions: 0.054
# Complaint type: Poison Ivy, correlation with evictions: 0.022
# Complaint type: Food Establishment, correlation with evictions: 0.005
# Complaint type: Beach/Pool/Sauna Complaint, correlation with evictions: 0.004
# Complaint type: Cooling Tower, correlation with evictions: 0.001
# Complaint type: Outside Building, correlation with evictions: 0.001
# Complaint type: AGENCY, correlation with evictions: -0.001
# Complaint type: Construction Lead Dust, correlation with evictions: -0.001
# Complaint type: Lifeguard, correlation with evictions: -0.002
# Complaint type: Radioactive Material, correlation with evictions: -0.003
