# %% [markdown]
# ### Use Folium
# (Folium only shows the clusters at a larger scale clearly, see ArcGIS for detailed visuals)

# %%
# folium is more clear
# takes a while and a lot of psace to load this map
# therefore, will not rerun, but upload a screenshot,
# to see the interactive effect, needs to be rerun

nyc_cluster_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# add cluster markers using Folium's MarkerCluster
marker_cluster = MarkerCluster().add_to(nyc_cluster_map)

# define a colormap for the clusters
# and create colormap
# map each cluster ID to a specific color
unique_clusters = set(evictions_manhattan_covid['cluster'])
colors = plt.cm.rainbow(np.linspace(0, 1, len(unique_clusters)))
# https://matplotlib.org/1.3.0/api/colors_api.html
cluster_color_map = {}
for i, cluster_id in enumerate(unique_clusters):
    color_hex = mcolors.rgb2hex(colors[i])
    cluster_color_map[cluster_id] = color_hex

for idx, row in evictions_manhattan_covid.iterrows():
    cluster_id = row['cluster']
    # set noise points are black if any, but we don't have them here.
    if cluster_id == -1:
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Noise",
                      icon=folium.Icon(color='black')).add_to(marker_cluster)
    else:
        color = cluster_color_map[cluster_id]
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Cluster: {cluster_id}",
                      icon=folium.Icon(color=color)).add_to(marker_cluster)

nyc_cluster_map

# %%
# folium is more clear
# takes a while and a lot of psace to load this map
# therefore, will not rerun, but upload a screenshot,
# to see the interactive effect, needs to be rerun

nyc_cluster_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# add cluster markers using Folium's MarkerCluster
marker_cluster = MarkerCluster().add_to(nyc_cluster_map)

# define a colormap for the clusters
# and create colormap
# map each cluster ID to a specific color
unique_clusters = set(evictions_manhattan_pre_post['cluster'])
colors = plt.cm.rainbow(np.linspace(0, 1, len(unique_clusters)))
# https://matplotlib.org/1.3.0/api/colors_api.html
cluster_color_map = {}
for i, cluster_id in enumerate(unique_clusters):
    color_hex = mcolors.rgb2hex(colors[i])
    cluster_color_map[cluster_id] = color_hex

for idx, row in evictions_manhattan_pre_post.iterrows():
    cluster_id = row['cluster']
    # set noise points are black if any, but we don't have them here.
    if cluster_id == -1:
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Noise",
                      icon=folium.Icon(color='black')).add_to(marker_cluster)
    else:
        color = cluster_color_map[cluster_id]
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Cluster: {cluster_id}",
                      icon=folium.Icon(color=color)).add_to(marker_cluster)

nyc_cluster_map

# %%
# folium is more clear
# takes a while and a lot of psace to load this map
# therefore, will not rerun, but upload a screenshot,
# to see the interactive effect, needs to be rerun

nyc_cluster_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# add cluster markers using Folium's MarkerCluster
marker_cluster = MarkerCluster().add_to(nyc_cluster_map)

# define a colormap for the clusters
# and create colormap
# map each cluster ID to a specific color
unique_clusters = set(evictions_brooklyn_covid['cluster'])
colors = plt.cm.rainbow(np.linspace(0, 1, len(unique_clusters)))
# https://matplotlib.org/1.3.0/api/colors_api.html
cluster_color_map = {}
for i, cluster_id in enumerate(unique_clusters):
    color_hex = mcolors.rgb2hex(colors[i])
    cluster_color_map[cluster_id] = color_hex

for idx, row in evictions_brooklyn_covid.iterrows():
    cluster_id = row['cluster']
    # set noise points are black if any, but we don't have them here.
    if cluster_id == -1:
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Noise",
                      icon=folium.Icon(color='black')).add_to(marker_cluster)
    else:
        color = cluster_color_map[cluster_id]
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Cluster: {cluster_id}",
                      icon=folium.Icon(color=color)).add_to(marker_cluster)

nyc_cluster_map

# %%
# folium is more clear
# takes a while and a lot of psace to load this map
# therefore, will not rerun, but upload a screenshot,
# to see the interactive effect, needs to be rerun

nyc_cluster_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# add cluster markers using Folium's MarkerCluster
marker_cluster = MarkerCluster().add_to(nyc_cluster_map)

# define a colormap for the clusters
# and create colormap
# map each cluster ID to a specific color
unique_clusters = set(evictions_brooklyn_pre_post['cluster'])
colors = plt.cm.rainbow(np.linspace(0, 1, len(unique_clusters)))
# https://matplotlib.org/1.3.0/api/colors_api.html
cluster_color_map = {}
for i, cluster_id in enumerate(unique_clusters):
    color_hex = mcolors.rgb2hex(colors[i])
    cluster_color_map[cluster_id] = color_hex

for idx, row in evictions_brooklyn_pre_post.iterrows():
    cluster_id = row['cluster']
    # set noise points are black if any, but we don't have them here.
    if cluster_id == -1:
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Noise",
                      icon=folium.Icon(color='black')).add_to(marker_cluster)
    else:
        color = cluster_color_map[cluster_id]
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Cluster: {cluster_id}",
                      icon=folium.Icon(color=color)).add_to(marker_cluster)

nyc_cluster_map

# %%
# folium is more clear
# takes a while and a lot of psace to load this map
# therefore, will not rerun, but upload a screenshot,
# to see the interactive effect, needs to be rerun

nyc_cluster_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# add cluster markers using Folium's MarkerCluster
marker_cluster = MarkerCluster().add_to(nyc_cluster_map)

# define a colormap for the clusters
# and create colormap
# map each cluster ID to a specific color
unique_clusters = set(evictions_bronx_covid['cluster'])
colors = plt.cm.rainbow(np.linspace(0, 1, len(unique_clusters)))
# https://matplotlib.org/1.3.0/api/colors_api.html
cluster_color_map = {}
for i, cluster_id in enumerate(unique_clusters):
    color_hex = mcolors.rgb2hex(colors[i])
    cluster_color_map[cluster_id] = color_hex

for idx, row in evictions_bronx_covid.iterrows():
    cluster_id = row['cluster']
    # set noise points are black if any, but we don't have them here.
    if cluster_id == -1:
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Noise",
                      icon=folium.Icon(color='black')).add_to(marker_cluster)
    else:
        color = cluster_color_map[cluster_id]
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Cluster: {cluster_id}",
                      icon=folium.Icon(color=color)).add_to(marker_cluster)

nyc_cluster_map

# %%
# folium is more clear
# takes a while and a lot of psace to load this map
# therefore, will not rerun, but upload a screenshot,
# to see the interactive effect, needs to be rerun

nyc_cluster_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# add cluster markers using Folium's MarkerCluster
marker_cluster = MarkerCluster().add_to(nyc_cluster_map)

# define a colormap for the clusters
# and create colormap
# map each cluster ID to a specific color
unique_clusters = set(evictions_bronx_pre_post['cluster'])
colors = plt.cm.rainbow(np.linspace(0, 1, len(unique_clusters)))
# https://matplotlib.org/1.3.0/api/colors_api.html
cluster_color_map = {}
for i, cluster_id in enumerate(unique_clusters):
    color_hex = mcolors.rgb2hex(colors[i])
    cluster_color_map[cluster_id] = color_hex

for idx, row in evictions_bronx_pre_post.iterrows():
    cluster_id = row['cluster']
    # set noise points are black if any, but we don't have them here.
    if cluster_id == -1:
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Noise",
                      icon=folium.Icon(color='black')).add_to(marker_cluster)
    else:
        color = cluster_color_map[cluster_id]
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Cluster: {cluster_id}",
                      icon=folium.Icon(color=color)).add_to(marker_cluster)

nyc_cluster_map

# %%
# folium is more clear
# takes a while and a lot of psace to load this map
# therefore, will not rerun, but upload a screenshot,
# to see the interactive effect, needs to be rerun

nyc_cluster_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# add cluster markers using Folium's MarkerCluster
marker_cluster = MarkerCluster().add_to(nyc_cluster_map)

# define a colormap for the clusters
# and create colormap
# map each cluster ID to a specific color
unique_clusters = set(evictions_si_covid['cluster'])
colors = plt.cm.rainbow(np.linspace(0, 1, len(unique_clusters)))
# https://matplotlib.org/1.3.0/api/colors_api.html
cluster_color_map = {}
for i, cluster_id in enumerate(unique_clusters):
    color_hex = mcolors.rgb2hex(colors[i])
    cluster_color_map[cluster_id] = color_hex

for idx, row in evictions_si_covid.iterrows():
    cluster_id = row['cluster']
    # set noise points are black if any, but we don't have them here.
    if cluster_id == -1:
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Noise",
                      icon=folium.Icon(color='black')).add_to(marker_cluster)
    else:
        color = cluster_color_map[cluster_id]
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Cluster: {cluster_id}",
                      icon=folium.Icon(color=color)).add_to(marker_cluster)

nyc_cluster_map

# %%
# folium is more clear
# takes a while and a lot of psace to load this map
# therefore, will not rerun, but upload a screenshot,
# to see the interactive effect, needs to be rerun

nyc_cluster_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# add cluster markers using Folium's MarkerCluster
marker_cluster = MarkerCluster().add_to(nyc_cluster_map)

# define a colormap for the clusters
# and create colormap
# map each cluster ID to a specific color
unique_clusters = set(evictions_si_pre_post['cluster'])
colors = plt.cm.rainbow(np.linspace(0, 1, len(unique_clusters)))
# https://matplotlib.org/1.3.0/api/colors_api.html
cluster_color_map = {}
for i, cluster_id in enumerate(unique_clusters):
    color_hex = mcolors.rgb2hex(colors[i])
    cluster_color_map[cluster_id] = color_hex

for idx, row in evictions_si_pre_post.iterrows():
    cluster_id = row['cluster']
    # set noise points are black if any, but we don't have them here.
    if cluster_id == -1:
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Noise",
                      icon=folium.Icon(color='black')).add_to(marker_cluster)
    else:
        color = cluster_color_map[cluster_id]
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Cluster: {cluster_id}",
                      icon=folium.Icon(color=color)).add_to(marker_cluster)

nyc_cluster_map

# %%
# folium is more clear
# takes a while and a lot of psace to load this map
# therefore, will not rerun, but upload a screenshot,
# to see the interactive effect, needs to be rerun

nyc_cluster_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# add cluster markers using Folium's MarkerCluster
marker_cluster = MarkerCluster().add_to(nyc_cluster_map)

# define a colormap for the clusters
# and create colormap
# map each cluster ID to a specific color
unique_clusters = set(evictions_queens_covid['cluster'])
colors = plt.cm.rainbow(np.linspace(0, 1, len(unique_clusters)))
# https://matplotlib.org/1.3.0/api/colors_api.html
cluster_color_map = {}
for i, cluster_id in enumerate(unique_clusters):
    color_hex = mcolors.rgb2hex(colors[i])
    cluster_color_map[cluster_id] = color_hex

for idx, row in evictions_queens_covid.iterrows():
    cluster_id = row['cluster']
    # set noise points are black if any, but we don't have them here.
    if cluster_id == -1:
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Noise",
                      icon=folium.Icon(color='black')).add_to(marker_cluster)
    else:
        color = cluster_color_map[cluster_id]
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Cluster: {cluster_id}",
                      icon=folium.Icon(color=color)).add_to(marker_cluster)

nyc_cluster_map

# %%
# folium is more clear
# takes a while and a lot of psace to load this map
# therefore, will not rerun, but upload a screenshot,
# to see the interactive effect, needs to be rerun

nyc_cluster_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# add cluster markers using Folium's MarkerCluster
marker_cluster = MarkerCluster().add_to(nyc_cluster_map)

# define a colormap for the clusters
# and create colormap
# map each cluster ID to a specific color
unique_clusters = set(evictions_queens_pre_post['cluster'])
colors = plt.cm.rainbow(np.linspace(0, 1, len(unique_clusters)))
# https://matplotlib.org/1.3.0/api/colors_api.html
cluster_color_map = {}
for i, cluster_id in enumerate(unique_clusters):
    color_hex = mcolors.rgb2hex(colors[i])
    cluster_color_map[cluster_id] = color_hex

for idx, row in evictions_queens_pre_post.iterrows():
    cluster_id = row['cluster']
    # set noise points are black if any, but we don't have them here.
    if cluster_id == -1:
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Noise",
                      icon=folium.Icon(color='black')).add_to(marker_cluster)
    else:
        color = cluster_color_map[cluster_id]
        folium.Marker(location=[row['latitude'], row['longitude']],
                      popup=f"Eviction Count: {row['average_year_eviction_count']}, Cluster: {cluster_id}",
                      icon=folium.Icon(color=color)).add_to(marker_cluster)

nyc_cluster_map

# %%
evictions_cleaned.crs = "EPSG:4326"  # WGS 84, the most common CRS for latitude/longitude

# %% [markdown]
# ### Part 3.3 K means (with k = 3 as given by DBSCAN)
#
# - doing this more like a confirmation/robustness test.
# - later analysis will only use the clusters identified by DBSCAN
# - both cluster algorithms here are trying to explain "magnitude of evictions"

# %%
eviction_covid_counts = evictions_covid[['average_year_eviction_count']]
eviction_pre_post_counts = evictions_pre_post[['average_year_eviction_count']]

# %%
# repeat the same procedures as DBSCAN.

eviction_covid_counts = evictions_covid[['average_year_eviction_count']]
scaler = StandardScaler()
eviction_counts_scaled = scaler.fit_transform(eviction_covid_counts)

k = 3
kmeans = KMeans(n_clusters=k, random_state=42)
evictions_covid['cluster_k'] = kmeans.fit_predict(eviction_counts_scaled)
centroids = kmeans.cluster_centers_

# %%
print("cluster centers: \n", centroids)
n_clusters = len(set(evictions_covid['cluster_k']))
print("number of clusters: ", n_clusters)
# Out:
# cluster centers:
#  [[ 0.63581804]
#  [-0.44048653]
#  [ 3.78079174]]
# number of clusters:  3

# %%
# repeat the same procedures as DBSCAN.

eviction_pre_post_counts = evictions_pre_post[['average_year_eviction_count']]
scaler = StandardScaler()
eviction_counts_scaled = scaler.fit_transform(eviction_pre_post_counts)

k = 3
kmeans = KMeans(n_clusters=k, random_state=42)
evictions_pre_post['cluster_k'] = kmeans.fit_predict(eviction_counts_scaled)
centroids = kmeans.cluster_centers_

# %%
print("cluster centers: \n", centroids)
n_clusters = len(set(evictions_pre_post['cluster_k']))
print("number of clusters: ", n_clusters)
# Out:
# cluster centers:
#  [[-0.1980085 ]
#  [ 7.12450201]
#  [ 1.56246567]]
# number of clusters:  3

# %%
evictions_covid[['average_year_eviction_count', 'cluster_k']].head()
# Out:
#    average_year_eviction_count  cluster_k
# 0                          1.0          1
# 1                          1.0          1
# 2                          1.0          1
# 3                          1.0          1
# 4                          1.0          1

# %%
evictions_pre_post[['average_year_eviction_count', 'cluster_k']].head()
# Out:
#    average_year_eviction_count  cluster_k
# 0                     2.600000          0
# 1                     1.000000          0
# 2                     4.000000          0
# 3                     2.666667          0
# 4                     3.000000          0

# %% [markdown]
# ### Part 3.3.1 Quck comparisons between DBSCAN and K means cluster classifications:

# %%
# evictions_pre_post.columns

# %%
evictions_covid['same_cluster'] = evictions_covid['cluster_k'] == evictions_covid['cluster']

same_cluster_count = evictions_covid['same_cluster'].sum()
total_points = len(evictions_covid)

print(same_cluster_count, "out of ", total_points, " points were assigned to the same cluster by both K-Means and DBSCAN.")
# Out:
# 1582 out of  6338  points were assigned to the same cluster by both K-Means and DBSCAN.

# %%
evictions_pre_post['same_cluster'] = evictions_pre_post['cluster_k'] == evictions_pre_post['cluster']

same_cluster_count = evictions_pre_post['same_cluster'].sum()
total_points = len(evictions_pre_post)

print(same_cluster_count, "out of ", total_points, " points were assigned to the same cluster by both K-Means and DBSCAN.")
# Out:
# 69251 out of  74082  points were assigned to the same cluster by both K-Means and DBSCAN.

# %%
# takes a long time to run
kmeans_silhouette = silhouette_score(eviction_covid_scaled, evictions_covid['cluster_k'])
dbscan_valid_points = evictions_covid[evictions_covid['cluster'] != -1]
dbscan_silhouette = silhouette_score(eviction_covid_scaled[dbscan_valid_points.index], dbscan_valid_points['cluster'])
print("K-Means silhouette score: ", kmeans_silhouette, "DBSCAN ss: ", dbscan_silhouette)
# Out:
# K-Means silhouette score:  0.8785528583473492 DBSCAN ss:  0.9003378797356034

# %%
kmeans_silhouette = silhouette_score(eviction_pre_post_scaled, evictions_pre_post['cluster_k'])
dbscan_valid_points = evictions_pre_post[evictions_pre_post['cluster'] != -1]
dbscan_silhouette = silhouette_score(eviction_pre_post_scaled[dbscan_valid_points.index], dbscan_valid_points['cluster'])
print("K-Means silhouette score: ", kmeans_silhouette, "DBSCAN ss: ", dbscan_silhouette)
# Out:
# K-Means silhouette score:  0.83374105897509 DBSCAN ss:  0.9299635928057535

# %% [markdown]
# #### Short summary:
#
# According to silhouette score, DBSCAN has a higher score (0.930) than K-Means (0.834). This indicates that DBSCAN is better at clustering evictions data based on the metrics used.

# %% [markdown]
# #### Underlying reasons why DBSCAN works better than K-means in this case:
#
# What Kmeans does is to use the given cluster number k and randomly initialize k centroids and then assign each data point to its nearrest centroid. Recalculate the distance and repeat until the convergence is achieved. It is assumed that the data somehow has some underlying centroids in them. However it is probably not the case with geo data if the streets/blocks/buildings are not arranged in a way that is closer to an imagined centroid. The DBSCAN works better because it is a density-based clustering, and our assumption/hypothesis that buildings who have higher eviction rates tend to be closer to each other fits the descriptions very well. DBSCAN can also discorver clusters of arbitrary shapes, where as kmeans assumes the clusters are spherical. ALso dcscan does not require a preassumption about the number of clusters. So it can go into the data and find its centers by itself.
#
# ##### source:
# https://www.geeksforgeeks.org/dbscan-clustering-in-ml-density-based-clustering/ \
# https://www.newhorizons.com/resources/blog/dbscan-vs-kmeans-a-guide-in-python \
# https://stanford.edu/~cpiech/cs221/handouts/kmeans.html

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.scatterplot(x=evictions_covid['longitude'],
                y=evictions_covid['latitude'],
                hue=evictions_covid['cluster_k'],
                palette='viridis',
                s=10,
                legend='full')
plt.title('K-Means clustering')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.subplot(1, 2, 2)
sns.scatterplot(x=evictions_covid['longitude'],
                y=evictions_covid['latitude'],
                hue=evictions_covid['cluster'],
                palette=['red', 'blue'],  # Custom color palette with just red and blue
                s=10,
                legend='full')
plt.title('DBSCAN clustering')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.scatterplot(x=evictions_pre_post['longitude'],
                y=evictions_pre_post['latitude'],
                hue=evictions_pre_post['cluster_k'],
                palette='viridis',
                s=10,
                legend='full')
plt.title('K-Means clustering')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.subplot(1, 2, 2)
sns.scatterplot(x=evictions_pre_post['longitude'],
                y=evictions_pre_post['latitude'],
                hue=evictions_pre_post['cluster'],
                palette=['red', 'blue'],  # Custom color palette with just red and blue
                s=10,
                legend='full')
plt.title('DBSCAN clustering')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.tight_layout()
plt.show()

# %%
evictions_pre_post.shape,\
evictions_covid.shape
# Out:
# ((74082, 24), (6338, 24))

# %%
# save cleaned evictions data to my drive
# evictions_cleaned.to_csv('/content/drive/My Drive/X999/evictions_cleaned.csv', index=False)

# %% [markdown]
# # Part 4: Analysis on the clusters (and further clusters will be included in Notebook 4)
